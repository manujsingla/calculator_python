# %%
a = int(input())
b = int(input())

print("Choose the operation'+,-,*,/'")
op=input()
if op == "+": print(a+b)
elif op == "-": print(a-b)
elif op == "*": print(a*b)
elif op == "/": print(a/b)
else: print("Enter valid operation")
# Out:
# 2
# 4
# Choose the operation'+,-,*,/'
# +
# 6
